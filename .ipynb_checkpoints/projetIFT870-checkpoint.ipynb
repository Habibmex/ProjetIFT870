# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# chargement des données

# %%
dataset=tf.keras.preprocessing.image_dataset_from_directory(
"../fruits/images",
    shuffle=True
)
# Out:
# Found 15628 files belonging to 15 classes.

# %%
#visualisation des nombres de classes
class_names=dataset.class_names
class_names
# Out:
# ['apple',
#  'avocado',
#  'banana',
#  'black berry',
#  'blueberry',
#  'coconut',
#  'corn kernel',
#  'kiwi',
#  'lemon',
#  'mandarine',
#  'mango',
#  'orange',
#  'pineapple',
#  'strawberry',
#  'tomato']

# %% [markdown]
# CREATION DES DONNEES (TRAIN AND TEST)

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# données d'entrainement

# %%
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
  "../fruits/images",
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 15628 files belonging to 15 classes.
# Using 12503 files for training.

# %% [markdown]
# données de validation

# %%
val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
  "../fruits/images",
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 15628 files belonging to 15 classes.
# Using 3125 files for validation.

# %%
#visualisation de l'ensemble des classes qui existent dans les donnes d'entrainement
class_names=train_dataset.class_names
print(class_names)
# Out:
# ['apple', 'avocado', 'banana', 'black berry', 'blueberry', 'coconut', 'corn kernel', 'kiwi', 'lemon', 'mandarine', 'mango', 'orange', 'pineapple', 'strawberry', 'tomato']

# %% [markdown]
# VISUALISATION DES DONNEES D'ENTRAITEMENT

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
# on peut aussi récuperer les lots d'images dans nos donneés 
for image_batch, labels_batch in train_dataset:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# il s'agit de lot de 32 images de la forme 180*180*32 avec un RVB égale à 32

# %% [markdown]
# CONFIGURATION DES DONNEES POUR LA PERFORMANCE

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE) 
val_dataset = val_dataset.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Standardisation des données

# %%
#nous allons normaliser la valeurs du RVB dans l'interval [0,1]
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_dataset = train_dataset.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_dataset))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %% [markdown]
# nous venons de normaliser les valeurs des canneaux entre 0 et 1 car nous devons avoir des entrées petites

# %% [markdown]
# CREATION DE NOTRE MODELE

# %% [markdown]
# nous allosn créer notre modèle avec 3 couches de convolutions conv2D, MAxpoling

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
#compilation de notre modèle 
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
#affichage des couhes de notre modèle 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 15)                1935
#
# =================================================================
# Total params: 3,990,575
# Trainable params: 3,990,575
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Former notre modèle

# %%
epochs=10
history = model.fit(
  train_dataset,
  validation_data=val_dataset,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 646s 2s/step - loss: 2.1945 - accuracy: 0.2728 - val_loss: 1.7312 - val_accuracy: 0.4144
# Epoch 2/10
# 391/391 [==============================] - 548s 1s/step - loss: 1.4738 - accuracy: 0.5203 - val_loss: 1.3866 - val_accuracy: 0.5482
# Epoch 3/10
# 391/391 [==============================] - 462s 1s/step - loss: 1.1742 - accuracy: 0.6154 - val_loss: 1.2815 - val_accuracy: 0.5872
# Epoch 4/10
# 391/391 [==============================] - 406s 1s/step - loss: 0.9415 - accuracy: 0.6919 - val_loss: 1.2337 - val_accuracy: 0.6198
# Epoch 5/10
# 391/391 [==============================] - 360s 920ms/step - loss: 0.7380 - accuracy: 0.7605 - val_loss: 1.2499 - val_accuracy: 0.6422
# Epoch 6/10
# 391/391 [==============================] - 391s 1s/step - loss: 0.5479 - accuracy: 0.8209 - val_loss: 1.4229 - val_accuracy: 0.6378
# Epoch 7/10
# 391/391 [==============================] - 334s 854ms/step - loss: 0.3900 - accuracy: 0.8741 - val_loss: 1.4864 - val_accuracy: 0.6602
# Epoch 8/10
# 391/391 [==============================] - 331s 846ms/step - loss: 0.2755 - accuracy: 0.9110 - val_loss: 1.6456 - val_accuracy: 0.6435
# Epoch 9/10
# 391/391 [==============================] - 343s 879ms/step - loss: 0.2141 - accuracy: 0.9327 - val_loss: 2.0292 - val_accuracy: 0.6410
# Epoch 10/10
# 391/391 [==============================] - 380s 973ms/step - loss: 0.1713 - accuracy: 0.9469 - val_loss: 1.9466 - val_accuracy: 0.6589

# %% [markdown]
# VISUALISATION DES RESULTATS D'ENTRAITEMENT

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
